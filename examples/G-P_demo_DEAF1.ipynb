# %% [markdown]
# # Structured Information Extraction with `DDLite`
#
# ### Gene-Phenotype Relation Extraction Demonstration
#
# In this demo, we'll be building a scalable machine learning & statistical inference-based information extraction system using an easy Jupyter Notebook interface.
#
# We will attempt to extract _gene-phenotype relation mentions_ from the scientific literature; in other words, any time there is a phrase expressing a causal relationship between a mutation in some gene and a phenotype (symptom), such as:
#
# > "A mutation in gene A is known to cause phenotype B"
#
# We want to extract a tuple `(A,B)` for our knowledgebase.  We'll start by loading the `ddlite` library:

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (18,6)

import cPickle, os, sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

from ddlite import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Candidate Extraction
#
# The first stage in our pipeline is to preprocess the set of input documents we will use, and extract a set of _candidates_ from

# %%
dp = DocParser('g-p-demo/deaf1_abstract.txt', TextParser())
sents = dp.parseDocSentences()
for doc in dp.parseDocs(): print doc
# Out:
# Recently, we identified in two individuals with intellectual disability (ID) different de novo mutations in DEAF1, which encodes a transcription factor with an important role in embryonic development. To ascertain whether these mutations in DEAF1 are causative for the ID phenotype, we performed targeted resequencing of DEAF1 in an additional cohort of over 2,300 individuals with unexplained ID and identified two additional individuals with de novo mutations in this gene. All four individuals had severe ID with severely affected speech development, and three showed severe behavioral problems. DEAF1 is highly expressed in the CNS, especially during early embryonic development. All four mutations were missense mutations affecting the SAND domain of DEAF1. Altered DEAF1 harboring any of the four amino acid changes showed impaired transcriptional regulation of the DEAF1 promoter. Moreover, behavioral studies in mice with a conditional knockout of Deaf1 in the brain showed memory deficits and increased anxiety-like behavior. Our results demonstrate that mutations in DEAF1 cause ID and behavioral problems, most likely as a result of impaired transcriptional regulation by DEAF1.

# %%
# Schema is: ENSEMBL_ID | NAME | TYPE (refseq, canonical, non-canonical)
genes = [line.rstrip().split('\t')[1] for line in open('g-p-demo/dicts/ensembl_genes.tsv')]
genes = filter(lambda g : len(g) > 3, genes)

# Schema is: HPO_ID | NAME | TYPE (exact, lemma)
phenos = [line.rstrip().split('\t')[1] for line in open('g-p-demo/dicts/pheno_terms.tsv')]

GM = DictionaryMatch('G', genes)
PM = DictionaryMatch('P', phenos)

# %%
R = Relations(sents, GM, PM)

# %%
R[4].render()
# Out:
# <style>
# .node {
#   cursor: pointer;
# }
#
# .node circle {
#   fill: #fff;
#   stroke: steelblue;
#   stroke-width: 3px;
# }
#
# .node text {
#   font: 12px sans-serif;
# }
#
# .edge {
#   fill: none;
#   stroke: #ccc;
#   stroke-width: 2px;
#   cursor: pointer;
# }
#
# .highlight {
#   stroke: red;
#   stroke-width: 3px;
# }
# </style>
#
# <!--Provide the canvas id (twice) and the words via python string formatting here--!>
# <div id="tree-chart-7612595535856258736"></div>
# <div id="raw-seq-7612595535856258736">
# <span class="word-7612595535856258736-0">Moreover</span> <span class="word-7612595535856258736-1">,</span> <span class="word-7612595535856258736-2">behavioral</span> <span class="word-7612595535856258736-3">studies</span> <span class="word-7612595535856258736-4">in</span> <span class="word-7612595535856258736-5">mice</span> <span class="word-7612595535856258736-6">with</span> <span class="word-7612595535856258736-7">a</span> <span class="word-7612595535856258736-8">conditional</span> <span class="word-7612595535856258736-9">knockout</span> <span class="word-7612595535856258736-10">of</span> <span class="word-7612595535856258736-11">Deaf1</span> <span class="word-7612595535856258736-12">in</span> <span class="word-7612595535856258736-13">the</span> <span class="word-7612595535856258736-14">brain</span> <span class="word-7612595535856258736-15">showed</span> <span class="word-7612595535856258736-16">memory</span> <span class="word-7612595535856258736-17">deficits</span> <span class="word-7612595535856258736-18">and</span> <span class="word-7612595535856258736-19">increased</span> <span class="word-7612595535856258736-20">anxiety-like</span> <span class="word-7612595535856258736-21">behavior</span> <span class="word-7612595535856258736-22">.</span>
# </div>

# %%
CM = CandidateModel(R)

# %%
CM
# Out:
# <ddlite.CandidateModel instance at 0x1112686c8>

# %%
R._get_features().keys()
# Out:
# ['INV_LEMMA:BETWEEN-MENTION-and-MENTION[mutation]',
#  'DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nsubj|study]',
#  'LEMMA:BETWEEN-MENTION-and-MENTION[study knockout]',
#  'LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None]',
#  'LEMMA:SEQ-BETWEEN[deficit and]',
#  'LEMMA:SEQ-BETWEEN[and increase]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|mutation nsubj|mutation acl|affect]',
#  'LEMMA:SEQ-BETWEEN[show memory deficit]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[mutation mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[result of impaired]',
#  'LEMMA:SEQ-BETWEEN[a conditional]',
#  'INV_LEMMA:SEQ-BETWEEN[mutation]',
#  'DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nsubj|study nmod|knockout]',
#  'INV_LEMMA:SEQ-BETWEEN[-rrb- different de]',
#  'LEMMA:SEQ-BETWEEN[with a conditional]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[id likely result]',
#  'INV_LEMMA:SEQ-BETWEEN[domain of]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[acl dobj]',
#  'INV_LEMMA:SEQ-BETWEEN[impaired transcriptional regulation]',
#  'LEMMA:BETWEEN-MENTION-and-MENTION[show study]',
#  'INV_LEMMA:SEQ-BETWEEN[missense mutation affect]',
#  'LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[study]',
#  'LEMMA:RIGHT-OF-MENTION[brain]',
#  'LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[that]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[identify individual]',
#  'LEMMA:RIGHT-OF-MENTION[knockout]',
#  'LEMMA:SEQ-BETWEEN[conditional]',
#  'INV_LEMMA:SEQ-BETWEEN[sand domain]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None demonstrate that]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[id result regulation]',
#  'DEP_LABEL:BETWEEN-MENTION-and-MENTION[nmod]',
#  'INV_LEMMA:SEQ-BETWEEN[be missense]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|id]',
#  'INV_LEMMA:RIGHT-OF-MENTION[four]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[mutation id]',
#  'LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[study knockout]',
#  'LEMMA:SEQ-BETWEEN[brain show memory]',
#  'INV_LEMMA:SEQ-BETWEEN[novo]',
#  'INV_LEMMA:SEQ-BETWEEN[as a result]',
#  'INV_LEMMA:SEQ-BETWEEN[of impaired transcriptional]',
#  'INV_LEMMA:RIGHT-OF-MENTION[,]',
#  'INV_LEMMA:SEQ-BETWEEN[affect the sand]',
#  'INV_LEMMA:SEQ-BETWEEN[four mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[transcriptional regulation by]',
#  'SEQ-BETWEEN[LEN:14-inf]',
#  'LEMMA:SEQ-BETWEEN[show]',
#  'INV_LEMMA:SEQ-BETWEEN[domain]',
#  'LEMMA:SEQ-BETWEEN[deficit and increase]',
#  'INV_LEMMA:SEQ-BETWEEN[be]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep nmod]',
#  'INV_LEMMA:SEQ-BETWEEN[, most]',
#  'LEMMA:SEQ-BETWEEN[of deaf1]',
#  'LEMMA:SEQ-BETWEEN[deaf1 in]',
#  'INV_LEMMA:SEQ-BETWEEN[the sand]',
#  'INV_LEMMA:SEQ-BETWEEN[four mutation be]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mutation nmod|id]',
#  'LEMMA:SEQ-BETWEEN[in]',
#  'DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|id]',
#  'INV_LEMMA:LEFT-OF-MENTION[sand]',
#  'LEMMA:SEQ-BETWEEN[conditional knockout]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT nsubj]',
#  'INV_LEMMA:SEQ-BETWEEN[sand domain of]',
#  'LEMMA:SEQ-BETWEEN[the]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nsubj|mutation acl|affect dobj|domain]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[mutation id result]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[that]',
#  'INV_LEMMA:SEQ-BETWEEN[id]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[regulation]',
#  'LEMMA:RIGHT-OF-MENTION[and]',
#  'LEMMA:RIGHT-OF-MENTION[.]',
#  'INV_LEMMA:SEQ-BETWEEN[mutation be]',
#  'LEMMA:FILTER-BY(pos=VB):BETWEEN-MENTION-and-MENTION[show]',
#  'LEMMA:SEQ-BETWEEN[and]',
#  'INV_LEMMA:SEQ-BETWEEN[most likely as]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[advmod|likely]',
#  'LEMMA:SEQ-BETWEEN[show memory]',
#  'LEMMA:SEQ-BETWEEN[a]',
#  'INV_LEMMA:SEQ-BETWEEN[likely as]',
#  'DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|show]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[id result]',
#  'LEMMA:LEFT-OF-MENTION[in]',
#  'INV_LEMMA:SEQ-BETWEEN[id -rrb- different]',
#  'INV_LEMMA:SEQ-BETWEEN[-rrb-]',
#  'DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dobj|domain]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nsubj acl dobj]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nsubj]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[domain]',
#  'INV_LEMMA:SEQ-BETWEEN[impaired]',
#  'INV_LEMMA:SEQ-BETWEEN[transcriptional regulation]',
#  'LEMMA:SEQ-BETWEEN[of]',
#  'INV_LEMMA:SEQ-BETWEEN[-lrb- id -rrb-]',
#  'LEMMA:SEQ-BETWEEN[knockout]',
#  'LEMMA:SEQ-BETWEEN[knockout of]',
#  'INV_LEMMA:FILTER-BY(pos=VB):BETWEEN-MENTION-and-MENTION[affect]',
#  'LEMMA:SEQ-BETWEEN[in the]',
#  'LEMMA:SEQ-BETWEEN[id]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[advmod|likely nmod|result]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[affect domain]',
#  'INV_BETWEEN-MENTION-and-MENTION[LEN:0-2]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep nmod advmod]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[mutation affect domain]',
#  'LEMMA:LEFT-OF-MENTION[and]',
#  'INV_LEMMA:SEQ-BETWEEN[of impaired]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[acl|affect dobj|domain]',
#  'INV_LEMMA:SEQ-BETWEEN[result of]',
#  'INV_LEMMA:SEQ-BETWEEN[novo mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[a result]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[domain]',
#  'DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|knockout]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[mutation mutation affect]',
#  'DEP_LABEL:BETWEEN-MENTION-and-MENTION[nsubj nmod]',
#  'INV_LEMMA:SEQ-BETWEEN[most likely]',
#  'INV_LEMMA:LEFT-OF-MENTION[two]',
#  'INV_LEMMA:SEQ-BETWEEN[transcriptional]',
#  'INV_BETWEEN-MENTION-and-MENTION[LEN:4-5]',
#  'DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT nsubj nmod]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mutation]',
#  'LEMMA:LEFT-OF-MENTION[study]',
#  'INV_LEMMA:SEQ-BETWEEN[the]',
#  'INV_LEMMA:SEQ-BETWEEN[regulation]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[advmod nmod]',
#  'LEMMA:SEQ-BETWEEN[deficit]',
#  'LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[that mutation]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[demonstrate]',
#  'INV_LEMMA:SEQ-BETWEEN[as a]',
#  'LEMMA:LEFT-OF-MENTION[conditional]',
#  'INV_LEMMA:SEQ-BETWEEN[sand]',
#  'LEMMA:BETWEEN-MENTION-and-MENTION[show study knockout]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|disability]',
#  'INV_LEMMA:SEQ-BETWEEN[by]',
#  'INV_LEMMA:SEQ-BETWEEN[different de]',
#  'INV_LEMMA:SEQ-BETWEEN[affect]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[regulation]',
#  'LEMMA:SEQ-BETWEEN[deaf1 in the]',
#  'LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[demonstrate that]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nmod nmod]',
#  'INV_LEMMA:SEQ-BETWEEN[in]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None]',
#  'INV_LEMMA:SEQ-BETWEEN[a]',
#  'INV_LEMMA:SEQ-BETWEEN[mutation be missense]',
#  'LEMMA:LEFT-OF-MENTION[behavioral]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[acl]',
#  'INV_LEMMA:SEQ-BETWEEN[likely as a]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nsubj|mutation acl|affect]',
#  'LEMMA:SEQ-BETWEEN[of deaf1 in]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[mutation mutation]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[individual]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[mutation id likely]',
#  'INV_SEQ-BETWEEN[LEN:8-13]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nmod advmod]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dobj]',
#  'LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[demonstrate that mutation]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[most]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[disability]',
#  'LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[id]',
#  'INV_LEMMA:SEQ-BETWEEN[of]',
#  'SEQ-BETWEEN[LEN:8-13]',
#  'DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|show nsubj|study]',
#  'INV_LEMMA:LEFT-OF-MENTION[transcriptional]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None identify]',
#  'DEP_LABEL:BETWEEN-MENTION-and-MENTION[nsubj]',
#  'LEMMA:SEQ-BETWEEN[cause id]',
#  'LEMMA:SEQ-BETWEEN[conditional knockout of]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None identify individual]',
#  'INV_LEMMA:SEQ-BETWEEN[be missense mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[a result of]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|mutation nsubj|mutation]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[None demonstrate]',
#  'LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[knockout]',
#  'BETWEEN-MENTION-and-MENTION[LEN:3-3]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[mutation domain]',
#  'LEMMA:BETWEEN-MENTION-and-MENTION[show]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[affect]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nmod dep]',
#  'LEMMA:SEQ-BETWEEN[the brain]',
#  'INV_LEMMA:SEQ-BETWEEN[-lrb- id]',
#  'INV_LEMMA:SEQ-BETWEEN[as]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[likely result]',
#  'INV_LEMMA:SEQ-BETWEEN[de]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[result regulation]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[identify]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[id]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[disability mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[mutation in]',
#  'INV_LEMMA:LEFT-OF-MENTION[and]',
#  'INV_LEMMA:SEQ-BETWEEN[mutation affect]',
#  'INV_LEMMA:SEQ-BETWEEN[de novo mutation]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|result]',
#  'LEMMA:SEQ-BETWEEN[with a]',
#  'INV_LEMMA:SEQ-BETWEEN[likely]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[disability mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[,]',
#  'LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[regulation by]',
#  'LEMMA:SEQ-BETWEEN[increase]',
#  'LEMMA:BETWEEN-MENTION-and-MENTION[id]',
#  'LEMMA:SEQ-BETWEEN[in the brain]',
#  'INV_LEMMA:SEQ-BETWEEN[de novo]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|disability dep|mutation]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[-lrb-]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[dep|mutation nmod|id advmod|likely]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[likely result regulation]',
#  'INV_LEMMA:SEQ-BETWEEN[-rrb- different]',
#  'INV_LEMMA:SEQ-BETWEEN[missense mutation]',
#  'DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[ROOT|show nsubj|study nmod|knockout]',
#  'INV_LEMMA:SEQ-BETWEEN[affect the]',
#  'INV_LEMMA:SEQ-BETWEEN[result]',
#  'LEMMA:BETWEEN-MENTION-and-MENTION[knockout]',
#  'LEMMA:SEQ-BETWEEN[with]',
#  'LEMMA:SEQ-BETWEEN[id and]',
#  'INV_LEMMA:LEFT-OF-MENTION[de]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[likely]',
#  'LEMMA:SEQ-BETWEEN[knockout of deaf1]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|result nmod|regulation]',
#  'LEMMA:SEQ-BETWEEN[memory]',
#  'LEMMA:RIGHT-OF-MENTION[cause]',
#  'INV_LEMMA:SEQ-BETWEEN[different]',
#  'SEQ-BETWEEN[LEN:0-4]',
#  'LEMMA:SEQ-BETWEEN[memory deficit and]',
#  'INV_LEMMA:SEQ-BETWEEN[four]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[acl|affect]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|regulation]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[mutation affect]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|id advmod|likely nmod|result]',
#  'LEMMA:SEQ-BETWEEN[deaf1]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[id]',
#  'LEMMA:SEQ-BETWEEN[the brain show]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[mutation id]',
#  'LEMMA:SEQ-BETWEEN[cause]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT nsubj acl]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nsubj|mutation]',
#  'INV_LEMMA:SEQ-BETWEEN[the sand domain]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[advmod|likely nmod|result nmod|regulation]',
#  'INV_LEMMA:SEQ-BETWEEN[impaired transcriptional]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[mutation mutation domain]',
#  'BETWEEN-MENTION-and-MENTION[LEN:0-2]',
#  'LEMMA:BETWEEN-MENTION-and-MENTION[study]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[dep]',
#  'LEMMA:SEQ-BETWEEN[memory deficit]',
#  'INV_LEMMA:SEQ-BETWEEN[novo mutation in]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nmod]',
#  'DEP_LABEL:BETWEEN-MENTION-and-MENTION[ROOT nsubj]',
#  'INV_LEMMA:FILTER-BY(pos=NN):BETWEEN-MENTION-and-MENTION[result]',
#  'LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[demonstrate]',
#  'LEMMA:SEQ-BETWEEN[brain show]',
#  'INV_DEP_LABEL|LEMMA:BETWEEN-MENTION-and-MENTION[nmod|id advmod|likely]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[result]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[id likely]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[advmod]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[disability]',
#  'INV_LEMMA:SEQ-BETWEEN[different de novo]',
#  'INV_LEMMA:SEQ-BETWEEN[, most likely]',
#  'INV_LEMMA:SEQ-BETWEEN[id -rrb-]',
#  'LEMMA:SEQ-BETWEEN[a conditional knockout]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nsubj acl]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[nmod advmod nmod]',
#  'INV_DEP_LABEL:BETWEEN-MENTION-and-MENTION[advmod nmod nmod]',
#  'INV_LEMMA:SEQ-BETWEEN[mutation affect the]',
#  'INV_LEMMA:SEQ-BETWEEN[missense]',
#  'LEMMA:SEQ-BETWEEN[cause id and]',
#  'INV_LEMMA:BETWEEN-MENTION-and-MENTION[result regulation]',
#  'INV_LEMMA:PARENTS-OF-BETWEEN-MENTION-and-MENTION[demonstrate that]',
#  'LEMMA:SEQ-BETWEEN[brain]']
